# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import os

# %%
# Import eurovision data

eurovision = pd.read_csv(os.path.join("../","data", "eurovision_data.csv"))
eurovision.head(5)
# Out:
#    Unnamed: 0          event host_city host_country  year       round  \
# 0           1  Helsinki 2007  Helsinki      Finland  2007  Semi-Final
# 1           2  Helsinki 2007  Helsinki      Finland  2007  Semi-Final
# 2           3  Helsinki 2007  Helsinki      Finland  2007  Semi-Final
# 3           4  Helsinki 2007  Helsinki      Finland  2007  Semi-Final
# 4           5  Helsinki 2007  Helsinki      Finland  2007  Semi-Final
#
#   participant_name                    song participant_country  running_order  \
# 0    Eric Papilaya  Get A Life - Get Alive             Austria           27.0
# 1    The KMGu0027s              Love Power             Belgium           24.0
# 2      Gerli Padar       Partners In Crime             Estonia           23.0
# 3        Anonymous       Salvem El Mu00f3n             Andorra           21.0
# 4     Olivia Lewis                 Vertigo               Malta           20.0
#
#    total_points rank_ordinal  rank qualified  winner  \
# 0           4.0         27th  27.0     False   False
# 1          14.0         26th  26.0     False   False
# 2          33.0         22nd  22.0     False   False
# 3          80.0         12th  12.0     False   False
# 4          15.0         25th  25.0     False   False
#
#                                   participant_link  \
# 0  https://eurovision.tv/participant/eric-papilaya
# 1      https://eurovision.tv/participant/the-kmg-s
# 2    https://eurovision.tv/participant/gerli-padar
# 3      https://eurovision.tv/participant/anonymous
# 4   https://eurovision.tv/participant/olivia-lewis
#
#                                   event_link
# 0  https://eurovision.tv/event/helsinki-2007
# 1  https://eurovision.tv/event/helsinki-2007
# 2  https://eurovision.tv/event/helsinki-2007
# 3  https://eurovision.tv/event/helsinki-2007
# 4  https://eurovision.tv/event/helsinki-2007

# %%
# Import world data

world = gpd.read_file(os.path.join("../","data", "World_Countries_Generalized.geojson"))
world.head(5)
# Out:
#    FID         COUNTRY ISO     COUNTRYAFF AFF_ISO  SHAPE_Length  SHAPE_Area  \
# 0    1     Afghanistan  AF    Afghanistan      AF     50.803210   62.566714
# 1    2         Albania  AL        Albania      AL      9.625038    3.073540
# 2    3         Algeria  DZ        Algeria      DZ     70.540082  213.513461
# 3    4  American Samoa  AS  United States      US      0.600124    0.013720
# 4    5         Andorra  AD        Andorra      AD      0.937352    0.055585
#
#                                             geometry
# 0  MULTIPOLYGON (((61.27655 35.60725, 61.29638 35...
# 1  MULTIPOLYGON (((19.57083 41.68527, 19.58195 41...
# 2  MULTIPOLYGON (((4.60335 36.88791, 4.63555 36.8...
# 3  MULTIPOLYGON (((-170.74390 -14.37555, -170.749...
# 4  MULTIPOLYGON (((1.44584 42.60194, 1.48653 42.6...

# %%
# Filter to final 1st and 2nd winner, summarise by count

winner = eurovision[(eurovision['round']=='Final') & (eurovision['rank']==1)][["year","participant_country","song","total_points"]].sort_values(by = 'total_points',ascending = False)
winner.head(5)
runnerup = eurovision[(eurovision['round']=='Final') & (eurovision['rank']==2)][["year","participant_country","song","total_points"]].sort_values(by = 'total_points',ascending = False)
runnerup.head(5)
# Out:
#      year participant_country              song  total_points
# 732  2017            Bulgaria    Beautiful Mess         615.0
# 744  2016           Australia  Sound Of Silence         511.0
# 630  2021              France         Voilu00e0         499.0
# 661  2019               Italy             Soldi         472.0
# 604  2022      United Kingdom         SPACE MAN         466.0

# %%
# Filter to final 1st and 2nd winner, summarise by count
winner_counts = pd.DataFrame(winner['participant_country'].value_counts())
winner_counts
# Out:
#                      count
# participant_country
# Ireland                  7
# Sweden                   6
# Netherlands              5
# Luxembourg               5
# France                   5
# United Kingdom           5
# Israel                   4
# Denmark                  3
# Ukraine                  3
# Italy                    3
# Norway                   3
# Switzerland              2
# Spain                    2
# Germany                  2
# Austria                  2
# Yugoslavia               1
# Latvia                   1
# Monaco                   1
# Turkey                   1
# Portugal                 1
# Belgium                  1
# Estonia                  1
# Azerbaijan               1
# Serbia                   1
# Russia                   1
# Finland                  1
# Greece                   1

# %%
runnerup_counts = pd.DataFrame(runnerup['participant_country'].value_counts())
runnerup_counts
# Out:
#                          count
# participant_country
# United Kingdom              16
# France                       7
# Germany                      6
# Italy                        5
# Ireland                      4
# Belgium                      4
# Russia                       4
# Switzerland                  4
# Spain                        4
# Netherlands                  3
# Malta                        2
# Israel                       2
# Luxembourg                   2
# Iceland                      2
# Ukraine                      2
# Norway                       1
# Sweden                       1
# Monaco                       1
# Bulgaria                     1
# Poland                       1
# Turkey                       1
# Australia                    1
# Azerbaijan                   1
# Serbia u0026 Montenegro      1
# Cyprus                       1
# Denmark                      1

# %%
winner_runnerup = winner_counts.merge(runnerup_counts, on = 'participant_country',how='outer',)
winner_runnerup.rename(columns = {'count_x':'wins','count_y':'runnerups'}, inplace = True)
winner_runnerup = winner_runnerup.replace(np.nan, 0)

winner_runnerup.head(5)
# Out:
#                      wins  runnerups
# participant_country
# Ireland               7.0        4.0
# Sweden                6.0        1.0
# Netherlands           5.0        3.0
# Luxembourg            5.0        2.0
# France                5.0        7.0

# %%
# New field = ratio
winner_runnerup["ratio"] = (winner_runnerup.runnerups / winner_runnerup.wins).round(2)
winner_runnerup
# Out:
#                          wins  runnerups  ratio
# participant_country
# Ireland                   7.0        4.0   0.57
# Sweden                    6.0        1.0   0.17
# Netherlands               5.0        3.0   0.60
# Luxembourg                5.0        2.0   0.40
# France                    5.0        7.0   1.40
# United Kingdom            5.0       16.0   3.20
# Israel                    4.0        2.0   0.50
# Denmark                   3.0        1.0   0.33
# Ukraine                   3.0        2.0   0.67
# Italy                     3.0        5.0   1.67
# Norway                    3.0        1.0   0.33
# Switzerland               2.0        4.0   2.00
# Spain                     2.0        4.0   2.00
# Germany                   2.0        6.0   3.00
# Austria                   2.0        0.0   0.00
# Yugoslavia                1.0        0.0   0.00
# Latvia                    1.0        0.0   0.00
# Monaco                    1.0        1.0   1.00
# Turkey                    1.0        1.0   1.00
# Portugal                  1.0        0.0   0.00
# Belgium                   1.0        4.0   4.00
# Estonia                   1.0        0.0   0.00
# Azerbaijan                1.0        1.0   1.00
# Serbia                    1.0        0.0   0.00
# Russia                    1.0        4.0   4.00
# Finland                   1.0        0.0   0.00
# Greece                    1.0        0.0   0.00
# Malta                     0.0        2.0    inf
# Iceland                   0.0        2.0    inf
# Bulgaria                  0.0        1.0    inf
# Poland                    0.0        1.0    inf
# Australia                 0.0        1.0    inf
# Serbia u0026 Montenegro   0.0        1.0    inf
# Cyprus                    0.0        1.0    inf

# %%
winner_runnerup['grouping'] = np.where(winner_runnerup.wins==0, "Runner-up but never won", "Runner-up and won at least once")
winner_runnerup
# Out:
#                          wins  runnerups  ratio  \
# participant_country
# Ireland                   7.0        4.0   0.57
# Sweden                    6.0        1.0   0.17
# Netherlands               5.0        3.0   0.60
# Luxembourg                5.0        2.0   0.40
# France                    5.0        7.0   1.40
# United Kingdom            5.0       16.0   3.20
# Israel                    4.0        2.0   0.50
# Denmark                   3.0        1.0   0.33
# Ukraine                   3.0        2.0   0.67
# Italy                     3.0        5.0   1.67
# Norway                    3.0        1.0   0.33
# Switzerland               2.0        4.0   2.00
# Spain                     2.0        4.0   2.00
# Germany                   2.0        6.0   3.00
# Austria                   2.0        0.0   0.00
# Yugoslavia                1.0        0.0   0.00
# Latvia                    1.0        0.0   0.00
# Monaco                    1.0        1.0   1.00
# Turkey                    1.0        1.0   1.00
# Portugal                  1.0        0.0   0.00
# Belgium                   1.0        4.0   4.00
# Estonia                   1.0        0.0   0.00
# Azerbaijan                1.0        1.0   1.00
# Serbia                    1.0        0.0   0.00
# Russia                    1.0        4.0   4.00
# Finland                   1.0        0.0   0.00
# Greece                    1.0        0.0   0.00
# Malta                     0.0        2.0    inf
# Iceland                   0.0        2.0    inf
# Bulgaria                  0.0        1.0    inf
# Poland                    0.0        1.0    inf
# Australia                 0.0        1.0    inf
# Serbia u0026 Montenegro   0.0        1.0    inf
# Cyprus                    0.0        1.0    inf
#
#                                                 grouping
# participant_country
# Ireland                  Runner-up and won at least once
# Sweden                   Runner-up and won at least once
# Netherlands              Runner-up and won at least once
# Luxembourg               Runner-up and won at least once
# France                   Runner-up and won at least once
# United Kingdom           Runner-up and won at least once
# Israel                   Runner-up and won at least once
# Denmark                  Runner-up and won at least once
# Ukraine                  Runner-up and won at least once
# Italy                    Runner-up and won at least once
# Norway                   Runner-up and won at least once
# Switzerland              Runner-up and won at least once
# Spain                    Runner-up and won at least once
# Germany                  Runner-up and won at least once
# Austria                  Runner-up and won at least once
# Yugoslavia               Runner-up and won at least once
# Latvia                   Runner-up and won at least once
# Monaco                   Runner-up and won at least once
# Turkey                   Runner-up and won at least once
# Portugal                 Runner-up and won at least once
# Belgium                  Runner-up and won at least once
# Estonia                  Runner-up and won at least once
# Azerbaijan               Runner-up and won at least once
# Serbia                   Runner-up and won at least once
# Russia                   Runner-up and won at least once
# Finland                  Runner-up and won at least once
# Greece                   Runner-up and won at least once
# Malta                            Runner-up but never won
# Iceland                          Runner-up but never won
# Bulgaria                         Runner-up but never won
# Poland                           Runner-up but never won
# Australia                        Runner-up but never won
# Serbia u0026 Montenegro          Runner-up but never won
# Cyprus                           Runner-up but never won

# %%
# Join spatial data
world_eurowins = world.merge(winner_runnerup,how='left', left_on ='COUNTRY', right_on='participant_country')
world_eurowins[world_eurowins['COUNTRY'] == 'Italy']
# Out:
#      FID COUNTRY ISO COUNTRYAFF AFF_ISO  SHAPE_Length  SHAPE_Area  \
# 111  112   Italy  IT      Italy      IT     68.044301   33.055064
#
#                                               geometry  wins  runnerups  \
# 111  MULTIPOLYGON (((12.75357 43.97100, 12.76472 43...   3.0        5.0
#
#      ratio                         grouping
# 111   1.67  Runner-up and won at least once

# %%
# Map
world_eurowins.to_file(os.path.join("../","data", "world_eurowins.geojson"), driver="GeoJSON")
