# %%
import pandas as pd
import numpy as np
import geopandas as gpd

# %%
# Load datasets for consumption and production

df_consumption = pd.read_csv("../data/coffee/coffeee/Coffee_domestic_consumption.csv")
df_production = pd.read_csv("../data/coffee/coffeee/Coffee_production.csv")

# %%
df_consumption.head(5)
# Out:
#                             Country      Coffee type    1990/91    1991/92  \
# 0                            Angola  Robusta/Arabica    1200000    1800000
# 1  Bolivia (Plurinational State of)          Arabica    1500000    1620000
# 2                            Brazil  Arabica/Robusta  492000000  510000000
# 3                           Burundi  Arabica/Robusta     120000      96000
# 4                           Ecuador  Arabica/Robusta   21000000   21000000
#
#      1992/93    1993/94    1994/95    1995/96    1996/97    1997/98  ...  \
# 0    2100000    1200000    1500000     600000    1200000    2400000  ...
# 1    1650000    1710000    1770000    1830000    1890000    1950000  ...
# 2  534000000  546000000  558000000  606000000  660000000  690000000  ...
# 3     102000     114600     120000     120000     120000     120000  ...
# 4   21000000   21000000   21000000   21000000   18000000   18000000  ...
#
# ...

# %%
df_production.head(5)
# Out:
#                             Country      Coffee type       1990/91  \
# 0                            Angola  Robusta/Arabica  3.000000e+06
# 1  Bolivia (Plurinational State of)          Arabica  7.380000e+06
# 2                            Brazil  Arabica/Robusta  1.637160e+09
# 3                           Burundi  Arabica/Robusta  2.922000e+07
# 4                           Ecuador  Arabica/Robusta  9.024000e+07
#
#         1991/92       1992/93       1993/94       1994/95       1995/96  \
# 0  4.740000e+06  4.680000e+06  1.980000e+06  4.620000e+06  3.720000e+06
# 1  6.240000e+06  7.200000e+06  3.060000e+06  7.020000e+06  8.520000e+06
# 2  1.637580e+09  2.076180e+09  1.690020e+09  1.691520e+09  1.083600e+09
# 3  4.002000e+07  3.720000e+07  2.358000e+07  3.984000e+07  2.604000e+07
# 4  1.274400e+08  7.110000e+07  1.241400e+08  1.425600e+08  1.132800e+08
#
#         1996/97       1997/98  ...       2011/12       2012/13       2013/14  \
# ...

# %%
# Join columns
df_joined = df_production.merge(df_consumption, on='Country', how='left')
df_joined = df_joined[["Country","Total_domestic_consumption","Total_production"]]
df_joined.head(5)
# Out:
#                             Country  Total_domestic_consumption  \
# 0                            Angola                    46500000
# 1  Bolivia (Plurinational State of)                    75180000
# 2                            Brazil                 27824700000
# 3                           Burundi                     3412020
# 4                           Ecuador                   381540000
#
#    Total_production
# 0      8.208000e+07
# 1      2.070000e+08
# 2      7.508298e+10
# 3      6.236400e+08
# 4      1.900380e+09

# %%
# Clean country names
df_joined.replace("Bolivia (Plurinational State of)", "Bolivia", inplace=True)
df_joined.replace("Viet Nam", "Vietnam", inplace=True)
df_joined.replace("Lao People's Democratic Republic","Laos", inplace=True)
df_joined.replace("Trinidad & Tobago", "Bolivia", inplace=True)
df_joined.replace("Democratic Republic of Congo", "Congo DRC", inplace=True)

# %%
# Read in geojson
world = gpd.read_file('../data/World_Countries_Generalized.geojson')
world.head(10)
# Out:
#    FID              COUNTRY ISO           COUNTRYAFF AFF_ISO  SHAPE_Length  \
# 0    1          Afghanistan  AF          Afghanistan      AF     50.803210
# 1    2              Albania  AL              Albania      AL      9.625038
# 2    3              Algeria  DZ              Algeria      DZ     70.540082
# 3    4       American Samoa  AS        United States      US      0.600124
# 4    5              Andorra  AD              Andorra      AD      0.937352
# 5    6               Angola  AO               Angola      AO     58.873470
# 6    7             Anguilla  AI       United Kingdom      GB      0.468389
# 7    8           Antarctica  AQ                                1564.144143
# 8    9  Antigua and Barbuda  AG  Antigua and Barbuda      AG      1.162901
# 9   10            Argentina  AR            Argentina      AR    138.751348
#
#     SHAPE_Area                                           geometry
# 0    62.566714  MULTIPOLYGON (((61.27655 35.60725, 61.29638 35...
# ...

# %%
# Clean up country names somehow
world_coffee = world.merge(df_joined,left_on='COUNTRY', right_on='Country',how='left')

# %%
# Export 
world_coffee.to_file("../data/coffee/coffee.geojson", driver="GeoJSON")

# %%
# df_joined_draft = df_joined.merge(world_coffee,left_on='Country', right_on='COUNTRY',how='left')
# df_joined_draft[df_joined_draft.geometry==None]
# Out:
# Empty DataFrame
# Columns: [Country_x, Total_domestic_consumption_x, Total_production_x, FID, COUNTRY, ISO, COUNTRYAFF, AFF_ISO, SHAPE_Length, SHAPE_Area, geometry, Country_y, Total_domestic_consumption_y, Total_production_y]
# Index: []
